# %% [markdown]
# ### DenseNet

# %%
#importing DenseNet from keras
#Access the pre-trained DenseNet121 model, a DL architecture for image classification tasks
from keras.applications.densenet import DenseNet121
#Define the layers of neural network
#Dense: fully connected layers
#GlobalAveragePooling2D: feature aggregation in CNNs
from keras.layers import Dense, GlobalAveragePooling2D
#Create and define custom neural network models
from keras.models import Model
#Provides access to backend functions of Keras
from keras import backend as K

import tensorflow as tf
#Control logging verbosity of tensorflow : suppress unnecessary log messages, making output less clustered during training
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
import os
folder_path = "./models/nih/"
files = os.listdir(folder_path)
print(files)
# Out:
# ['densenet.hdf5']

# %%
#Create the base pre-trained model
#pre-trained weights contain the learned parameters from training on a large dataset (typically ImageNet) and will be used as a starting point for fine-tuning on your specific task.
#he include_top parameter is set to False, which means that you are excluding the top (output) layer of the model
base_model = DenseNet121(weights='./models/nih/densenet.hdf5',include_top=False);

# %%
#Print the summary of the model
base_model.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  zero_padding2d (ZeroPaddin  (None, None, None, 3)        0         ['input_1[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, None, None, 64)       9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, None, None, 64)       256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, None, None, 64)       0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, None, None, 64)       0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, None, None, 64)       0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, None, None, 64)       256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, None, None, 64)       0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, None, None, 128)      8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, None, None, 128)      512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, None, None, 128)      0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, None, None, 32)       36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, None, None, 96)       0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, None, None, 96)       384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, None, None, 96)       0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, None, None, 128)      12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, None, None, 128)      512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, None, None, 128)      0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, None, None, 32)       36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, None, None, 128)      0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, None, None, 128)      512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, None, None, 128)      0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, None, None, 128)      16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, None, None, 128)      512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, None, None, 128)      0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, None, None, 32)       36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, None, None, 160)      0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#  conv2_block4_0_bn (BatchNo  (None, None, None, 160)      640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, None, None, 160)      0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, None, None, 128)      20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, None, None, 128)      512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, None, None, 128)      0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, None, None, 32)       36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, None, None, 192)      0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, None, None, 192)      768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, None, None, 192)      0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, None, None, 128)      24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, None, None, 128)      512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, None, None, 128)      0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, None, None, 32)       36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, None, None, 224)      0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, None, None, 224)      896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, None, None, 224)      0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, None, None, 128)      28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, None, None, 128)      512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, None, None, 128)      0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, None, None, 32)       36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, None, None, 256)      0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, None, None, 256)      1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, None, None, 256)      0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, None, None, 128)      32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, None, None, 128)      0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, None, None, 128)      512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, None, None, 128)      0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, None, None, 128)      16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, None, None, 32)       36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, None, None, 160)      0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, None, None, 160)      640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, None, None, 160)      0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, None, None, 128)      20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, None, None, 32)       36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, None, None, 192)      0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, None, None, 192)      768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, None, None, 192)      0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, None, None, 128)      24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, None, None, 32)       36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, None, None, 224)      0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, None, None, 224)      896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, None, None, 224)      0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, None, None, 128)      28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, None, None, 32)       36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, None, None, 256)      0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, None, None, 256)      1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, None, None, 256)      0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, None, None, 128)      32768     ['conv3_block5_0_relu[0][0]']
#  D)
#  conv3_block5_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, None, None, 32)       36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, None, None, 288)      0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, None, None, 288)      1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, None, None, 288)      0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, None, None, 128)      36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, None, None, 32)       36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, None, None, 320)      0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, None, None, 320)      1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, None, None, 320)      0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, None, None, 128)      40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, None, None, 32)       36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, None, None, 352)      0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, None, None, 352)      1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, None, None, 352)      0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, None, None, 128)      45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, None, None, 32)       36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, None, None, 384)      0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, None, None, 384)      1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, None, None, 384)      0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, None, None, 128)      49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, None, None, 128)      512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, None, None, 128)      0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, None, None, 32)       36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, None, None, 416)      0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, None, None, 416)      1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, None, None, 416)      0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, None, None, 128)      53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, None, None, 128)      512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, None, None, 128)      0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, None, None, 32)       36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, None, None, 448)      0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, None, None, 448)      1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, None, None, 448)      0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, None, None, 128)      57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, None, None, 128)      512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, None, None, 128)      0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, None, None, 32)       36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, None, None, 480)      0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, None, None, 480)      1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, None, None, 480)      0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, None, None, 128)      61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, None, None, 128)      512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, None, None, 128)      0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, None, None, 32)       36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, None, None, 512)      0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, None, None, 512)      2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, None, None, 512)      0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, None, None, 256)      131072    ['pool3_relu[0][0]']
#  pool3_pool (AveragePooling  (None, None, None, 256)      0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, None, None, 256)      1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, None, None, 256)      0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, None, None, 128)      32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, None, None, 128)      512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, None, None, 128)      0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, None, None, 32)       36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, None, None, 288)      0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, None, None, 288)      1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, None, None, 288)      0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, None, None, 128)      36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, None, None, 128)      512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, None, None, 128)      0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, None, None, 32)       36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, None, None, 320)      0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, None, None, 320)      1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, None, None, 320)      0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, None, None, 128)      40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, None, None, 128)      512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, None, None, 128)      0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, None, None, 32)       36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, None, None, 352)      0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, None, None, 352)      1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
#  conv4_block4_0_relu (Activ  (None, None, None, 352)      0         ['conv4_block4_0_bn[0][0]']
#  ation)
#
#  conv4_block4_1_conv (Conv2  (None, None, None, 128)      45056     ['conv4_block4_0_relu[0][0]']
#  D)
# ...
#
#  conv5_block9_2_conv (Conv2  (None, None, None, 32)       36864     ['conv5_block9_1_relu[0][0]']
#  D)
#
#  conv5_block9_concat (Conca  (None, None, None, 800)      0         ['conv5_block8_concat[0][0]',
#  tenate)                                                             'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchN  (None, None, None, 800)      3200      ['conv5_block9_concat[0][0]']
#  ormalization)
#
#  conv5_block10_0_relu (Acti  (None, None, None, 800)      0         ['conv5_block10_0_bn[0][0]']
#  vation)
#
#  conv5_block10_1_conv (Conv  (None, None, None, 128)      102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, None, None, 128)      512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, None, None, 128)      0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, None, None, 32)       36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, None, None, 832)      0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, None, None, 832)      3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, None, None, 832)      0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, None, None, 128)      106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, None, None, 128)      512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, None, None, 128)      0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, None, None, 32)       36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, None, None, 864)      0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, None, None, 864)      3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, None, None, 864)      0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, None, None, 128)      110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, None, None, 128)      512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, None, None, 128)      0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, None, None, 32)       36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, None, None, 896)      0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, None, None, 896)      3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, None, None, 896)      0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, None, None, 128)      114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, None, None, 128)      512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, None, None, 128)      0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, None, None, 32)       36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, None, None, 928)      0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, None, None, 928)      3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, None, None, 928)      0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, None, None, 128)      118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, None, None, 128)      512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, None, None, 128)      0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, None, None, 32)       36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, None, None, 960)      0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, None, None, 960)      3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, None, None, 960)      0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, None, None, 128)      122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, None, None, 128)      512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, None, None, 128)      0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, None, None, 32)       36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, None, None, 992)      0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, None, None, 992)      3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, None, None, 992)      0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, None, None, 128)      126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, None, None, 128)      512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, None, None, 128)      0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, None, None, 32)       36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, None, None, 1024)     0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, None, None, 1024)     4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, None, None, 1024)     0         ['bn[0][0]']
#
# ==================================================================================================
# Total params: 7037504 (26.85 MB)
# Trainable params: 6953856 (26.53 MB)
# Non-trainable params: 83648 (326.75 KB)
# __________________________________________________________________________________________________

# %%
#Print out first 5 layers
layers_l = base_model.layers
print("First 5 layers")
layers_l[0:5]
# Out:
# First 5 layers
# [<keras.src.engine.input_layer.InputLayer at 0x168a4bc90>,
#  <keras.src.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x10b55cd50>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x2876ad210>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x285632a50>,
#  <keras.src.layers.core.activation.Activation at 0x168a4bad0>]

# %%
# print last 5 layers
print("Last 5 layers")
layers_l[-6:-1]
# Out:
# Last 5 layers
# [<keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x290f34e50>,
#  <keras.src.layers.core.activation.Activation at 0x290f62810>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x290fcbb90>,
#  <keras.src.layers.merging.concatenate.Concatenate at 0x290fd60d0>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x290f99f50>]

# %%
#Get the convulation layers and pring first 5
conv2d_layers = [layer for layer in base_model.layers
                if str(type(layer)).find('Conv2D')>-1]
print("The first five conv2D layers")
conv2d_layers[0:5]
# Out:
# The first five conv2D layers
# [<keras.src.layers.convolutional.conv2d.Conv2D at 0x2876ad210>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x287671ed0>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x2873b0b10>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x287659450>,
#  <keras.src.layers.convolutional.conv2d.Conv2D at 0x290b41ad0>]

# %%
#Print out total number of convulational layers
print(f"There are {len(conv2d_layers)} convulational layers")
# Out:
# There are 120 convulational layers

# %%
#Print the number of input channels
print("The input has 3 channels")
base_model.input
# Out:
# The input has 3 channels
# <KerasTensor: shape=(None, None, None, 3) dtype=float32 (created by layer 'input_1')>

# %%
#Print the number of output channels
print("The output has 1024 channels")
x = base_model.output
x
# Out:
# The output has 1024 channels
# <KerasTensor: shape=(None, None, None, 1024) dtype=float32 (created by layer 'relu')>

# %%
#Add a global spatial average pooling layer
# Global Average Pooling (GAP) layer is a common technique used to reduce the spatial dimensions of the feature maps before feeding them into the fully connected layers in a neural network.
x_pool = GlobalAveragePooling2D()(x)
x_pool
# Out:
# <KerasTensor: shape=(None, 1024) dtype=float32 (created by layer 'global_average_pooling2d')>

# %%
#Define a set of 5 class labels to use as an example
labels =['Emphysema',
        'Hernia',
        'Mass',
        'Pneumonia',
        'Edema',]
n_classes = len(labels)
print(f"In this example, you want your model to identify {n_classes} classes")
# Out:
# In this example, you want your model to identify 5 classes

# %%
#Add a logistic layer the same size as the number of classes you're trying to predict
#For the purpose of multi-label classification
#Sigmoid : squashes the network's output into the range [0, 1] for each output unit
predictions = Dense(n_classes, activation="sigmoid")(x_pool)
print("Predictions have {n_classes} units, one for each class")
predictions
# Out:
# Predictions have {n_classes} units, one for each class
# <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'dense')>

# %%
#Create an updated model
model = Model(inputs=base_model.input, outputs = predictions)

# %%
#compile the dataset
model.compile(optimizer='adam',
              loss='categorical_crossentropy')

# %%
width = 0.2
x = np.arange(len(methods))

fig, ax = plt.subplots()

ax.bar(x - width, precision, width, label='Precision')
ax.bar(x, accuracy, width, label='Accuracy')
ax.bar(x + width, recall, width, label='Recall')

ax.set_xlabel('Methods')
ax.set_ylabel('Scores')
ax.set_title('Classification Results')
ax.set_xticks(x)
ax.set_xticklabels(methods)
ax.legend()

plt.show()
